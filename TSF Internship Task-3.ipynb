# %% [markdown]
# # Author : Swastika Nath

# %% [markdown]
# # Data Science & Business Analytics Internship

# %% [markdown]
# # GRIP @ The Sparks Foundation

# %% [markdown]
# ## Batch : October, 2023

# %% [markdown]
# #### Task-3 : Performing ' Exploratory Data Analysis' on dataset 'SamplesSuperstore'
#
# #### As a business manager, try to find out the weak areas where you can work to make more profit. What all business problems you can derive by exploring the data?

# %% [markdown]
# **Step 1 : Importing the required python libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Step 2 : Importing and reading the data**

# %%
df = pd.read_csv("C:\\Users\\DELL\\Downloads\\SampleSuperstore.csv")

# head() shows the first 5 values of the dataset
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# seeing the last 5 values of the dataset
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# **Step 3 : Data Exploration**

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# The data has 13 features and 9994 lables included

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# checking for the datatypes
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# **Checking for null values**

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset

# %% [markdown]
# **Exploring the summary statistics**

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# From the above statistics we can see that
# - The average sales made is approximately 229.86, with a minimum of 0.44 and a maximum of 22,638.28.
# - The sales distribution has a relatively hifh standard diviation 623.25, indicating significant variability in sales.
# - The average quantity of products sold is around 3.79.
# - The quantity distribution has a standard deviation of 2.23, suggesting moderate variability in the number of items sold.
# - On average, a discount of 15.62% is given , with a minimum of 0% and a maximum of 80%.
# - A negative profit margin is when production costs are more that revenue, since it is minimum thats good
# - Average profit made is 29

# %% [markdown]
# **Checking for column wise unique values**

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# - There are 3 types in segment.
#
# - There are 4 regions
#
# - 3 categories and 17 subcategories

# %% [markdown]
# **Checking for duplicate values**

# %%
print('No. of Duplicate rows : ', df.duplicated().sum())
# Out:
# No. of Duplicate rows :  17

# %%
# dropping the duplicates
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ### Data Visualization

# %%
# correlation analysis using heatmap

df.corr(numeric_only= True)
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(numeric_only= True), annot=True)
plt.show()

# %%
# visualizing using the scatter plot

num = ['Sales','Quantity','Discount','Profit']
num_df = df[num]
g = sns.PairGrid(num_df)
g.map(sns.scatterplot)

# %% [markdown]
# - Profit and Sales - The profit is clustered around the 0 and no visible increase in profits as sale increases. It shows that the sales does not affect the profit.
# - Qquantity is also not correlated to profit. As discount increases, we can see that profit decreases.

# %% [markdown]
# #### Univariate Analysis

# %%
df["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
sns.countplot(x='Ship Mode',data=df)
plt.show()

# %% [markdown]
# 'Standard Class' is highly prefered, while least being the ones on 'Same Day'

# %%
df["Segment"].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
sns.countplot(x='Segment',data=df)
plt.show()

# %% [markdown]
# Most people belong to the consumer segment and rest belong to Corporate and Home Office

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
sns.countplot(x='Category',data=df)
plt.show()

# %% [markdown]
# Most of the Category belong to Office Supplies and rest belong to the Furniture and Technology supplies

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df['Sub-Category'].value_counts().plot(kind = 'pie', figsize = [10,10], autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Popularly sold items in the superstore are Binders followed by Paper and furnishing .

# %%
df['City'].value_counts().head(10)
# Out:
# City
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163
# Name: count, dtype: int64

# %%
df['City'].value_counts().head(10).plot(kind = 'barh')
plt.title('Top 10 Cities having the most orders placed')
# Out:
# Text(0.5, 1.0, 'Top 10 Cities having the most orders placed')

# %% [markdown]
#  New York City has the most no. of orders placed

# %%
df['State'].value_counts().head(10)
# Out:
# State
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: count, dtype: int64

# %%
df['State'].value_counts().head(10).sort_values(ascending = True).plot(kind = 'bar', figsize =[20,6])
plt.title('State wise order distribution')
# Out:
# Text(0.5, 1.0, 'State wise order distribution')

# %% [markdown]
# The most no of orders are placed from  California

# %%
df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
plt.figure(figsize=[15,5])
sns.countplot(x='Region',data=df)
plt.show()

# %% [markdown]
# West region has the highest no. of sales

# %% [markdown]
# #### Bivariate Analysis

# %%
categorical_count= df.groupby("Category").sum(numeric_only= True)
print(categorical_count)
# Out:
#                  Postal Code        Sales  Quantity  Discount       Profit
# Category
# Furniture          118196026  741999.7953      8028    368.89   18451.2728
# Office Supplies    330772872  719047.0320     22906    947.80  122490.8008
# Technology         102603754  836154.0330      6939    244.40  145454.9481

# %%
categorical_count[['Sales', 'Profit']].plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
subcategorical_sum= df.groupby("Sub-Category").sum(numeric_only=True)
subcategorical_sum
# Out:
#               Postal Code        Sales  Quantity  Discount      Profit
# Sub-Category
# Accessories      44468434  167380.3180      2976     60.80  41936.6357
# Appliances       25250538  107532.1610      1729     77.60  18138.0054
# Art              43329658   27118.7920      3000     59.60   6527.7870
# Binders          83626398  203412.7330      5974    567.00  30221.7633
# Bookcases        12771539  114879.9963       868     48.14  -3472.5560
# Chairs           34936229  328449.1030      2356    105.00  26590.1663
# Copiers           3873477  149528.0300       234     11.00  55617.8249
# Envelopes        13325731   16476.4020       906     20.40   6964.1767
# Fasteners        12506063    3024.2800       914     17.80    949.5182
# Furnishings      51880430   91705.1640      3563    132.40  13059.1436
# Labels           19552985   12486.3120      1400     25.00   5546.2540
# Machines          6364668  189238.6310       440     35.20   3384.7569
# ...

# %%
subcategorical_sum[['Sales', 'Profit']].plot(kind = 'bar', figsize = [20,8])
plt.ylabel('Total Sales Vs Profits',fontsize = 18)
# Out:
# Text(0, 0.5, 'Total Sales Vs Profits')

# %%
# category vs sub-category analysis

plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category', data=df)
plt.title('Category vs Sub Category')
plt.xlabel('Sub-Catgory')
plt.ylabel('Category')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Discount',y='Profit',data=df)
plt.title("Discount vs Profit")
# Out:
# Text(0.5, 1.0, 'Discount vs Profit')

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Discount',y='Sales',data=df)
plt.title('Discount VS Sales')
# Out:
# Text(0.5, 1.0, 'Discount VS Sales')

# %% [markdown]
# **Observation**
#
# - Quantity is not correlated to profit. As discount increases, we can see that profit decreases.
# - Since phones are the most profitable and sold items, an opportunity for cross-selling related accessories, such as phone cases, screen protectors, or chargers, to boost sales and profits further.
# -
# Since consumers are the profitable and high selling segment, more marketing and product strategies should be focused on the consumers needs and preferences.-
# Clearence sales can be held to encourage the sales of least profitable items like envelopes, storage and accessories- .
# Standard is the most profitable shipping mode, this might be the reason due to it being cost-effect
# - There is huge loss on the sale of tables. So its sale should be minimized.
# - States like 'New York' and 'California'e shoul be  concentratde to make more profits.iveective
